# %%
a=5
a
# Out:
# 5

# %%
import merhaba

merhaba.merhaba("ali", 30)

kimsin=merhaba.kimsin('veli', 20)
kimsin
# Out:
# Merhaba ALI, senin yasin 30
# 'Merhaba ben veli, 20 yasindayim'

# %%
isim='Mustafa'
isim[3]
# Out:
# 't'

# %%
isim='Mustafa'
isim[1:3]
# Out:
# 'us'

# %%
isim='Mustafa'
isim[1:]
# Out:
# 'ustafa'

# %%
isim='Mustafa'
isim[-2]
# Out:
# 'f'

# %%
isim='Mustafa'
isim[-4:-1]
# Out:
# 'taf'

# %%
isim='Mustafa'
isim.find('af')
# Out:
# 4

# %%
isim='Mustafa'
isim[1:]
# Out:
# 'ustafa'

# %%
import torch

x = torch.tensor([1, 2, 3])
y = torch.tensor([4, 5, 6])

z = x + y

print(z)
# Out:
# tensor([5, 7, 9])

# %%
import torch.nn as nn

x = torch.tensor([
    [1.0, 2.0, 3.0]
])

model = nn.Linear(3, 1)

output = model(x)

output
# Out:
# tensor([[0.8185]], grad_fn=<AddmmBackward0>)

# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

print("PyTorch version:", torch.__version__)
vector = torch.tensor([3,4,5,6,7], )
print("CUDA available:", torch.cuda.is_available())
print("PyTorch CUDA version:", torch.version.cuda)    

print(torch.get_num_threads())
print(torch.cuda.device_count())
# Out:
# False
# PyTorch version: 2.8.0+cpu
# CUDA available: False
# PyTorch CUDA version: None
# 14
# 0

# %%
import torch
scalar = torch.tensor(5)
print(scalar)
print(scalar.shape)
print(scalar.ndim)
# Out:
# tensor(5)
# torch.Size([])
# 0
